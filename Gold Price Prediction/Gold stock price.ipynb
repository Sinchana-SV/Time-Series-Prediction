# %%
# !pip install prophet
# Out:
# Collecting prophet
#   Downloading prophet-1.2.1-py3-none-win_amd64.whl.metadata (3.6 kB)
# Collecting cmdstanpy>=1.0.4 (from prophet)
#   Downloading cmdstanpy-1.3.0-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: numpy>=1.15.4 in f:\pythonnn\lib\site-packages (from prophet) (2.1.3)
# Requirement already satisfied: matplotlib>=2.0.0 in f:\pythonnn\lib\site-packages (from prophet) (3.10.0)
# Requirement already satisfied: pandas>=1.0.4 in f:\pythonnn\lib\site-packages (from prophet) (2.2.3)
# Collecting holidays<1,>=0.25 (from prophet)
#   Downloading holidays-0.86-py3-none-any.whl.metadata (50 kB)
# Requirement already satisfied: tqdm>=4.36.1 in f:\pythonnn\lib\site-packages (from prophet) (4.67.1)
# Collecting importlib_resources (from prophet)
#   Downloading importlib_resources-6.5.2-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: python-dateutil in f:\pythonnn\lib\site-packages (from holidays<1,>=0.25->prophet) (2.9.0.post0)
# Collecting stanio<2.0.0,>=0.4.0 (from cmdstanpy>=1.0.4->prophet)
#   Downloading stanio-0.5.1-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: contourpy>=1.0.1 in f:\pythonnn\lib\site-packages (from matplotlib>=2.0.0->prophet) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in f:\pythonnn\lib\site-packages (from matplotlib>=2.0.0->prophet) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in f:\pythonnn\lib\site-packages (from matplotlib>=2.0.0->prophet) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in f:\pythonnn\lib\site-packages (from matplotlib>=2.0.0->prophet) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in f:\pythonnn\lib\site-packages (from matplotlib>=2.0.0->prophet) (24.2)
# Requirement already satisfied: pillow>=8 in f:\pythonnn\lib\site-packages (from matplotlib>=2.0.0->prophet) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in f:\pythonnn\lib\site-packages (from matplotlib>=2.0.0->prophet) (3.2.0)
# Requirement already satisfied: pytz>=2020.1 in f:\pythonnn\lib\site-packages (from pandas>=1.0.4->prophet) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in f:\pythonnn\lib\site-packages (from pandas>=1.0.4->prophet) (2025.2)
# Requirement already satisfied: six>=1.5 in f:\pythonnn\lib\site-packages (from python-dateutil->holidays<1,>=0.25->prophet) (1.17.0)
# Requirement already satisfied: colorama in f:\pythonnn\lib\site-packages (from tqdm>=4.36.1->prophet) (0.4.6)
# Downloading prophet-1.2.1-py3-none-win_amd64.whl (12.1 MB)
#    ---------------------------------------- 0.0/12.1 MB ? eta -:--:--
#     --------------------------------------- 0.3/12.1 MB ? eta -:--:--
#    -- ------------------------------------- 0.8/12.1 MB 3.9 MB/s eta 0:00:03
#    ---- ----------------------------------- 1.3/12.1 MB 3.2 MB/s eta 0:00:04
#    ----- ---------------------------------- 1.6/12.1 MB 2.9 MB/s eta 0:00:04
#    -------- ------------------------------- 2.6/12.1 MB 2.8 MB/s eta 0:00:04
#    ---------- ----------------------------- 3.1/12.1 MB 2.8 MB/s eta 0:00:04
#    ----------- ---------------------------- 3.4/12.1 MB 2.8 MB/s eta 0:00:04
#    ------------ --------------------------- 3.9/12.1 MB 2.5 MB/s eta 0:00:04
#    ------------- -------------------------- 4.2/12.1 MB 2.5 MB/s eta 0:00:04
#    -------------- ------------------------- 4.5/12.1 MB 2.4 MB/s eta 0:00:04
#    ---------------- ----------------------- 5.0/12.1 MB 2.2 MB/s eta 0:00:04
#    ------------------ --------------------- 5.5/12.1 MB 2.3 MB/s eta 0:00:03
#    ------------------- -------------------- 5.8/12.1 MB 2.3 MB/s eta 0:00:03
#    ------------------- -------------------- 6.0/12.1 MB 2.2 MB/s eta 0:00:03
#    -------------------- ------------------- 6.3/12.1 MB 2.2 MB/s eta 0:00:03
#    --------------------- ------------------ 6.6/12.1 MB 2.1 MB/s eta 0:00:03
#    ---------------------- ----------------- 6.8/12.1 MB 2.0 MB/s eta 0:00:03
#    ---------------------- ----------------- 6.8/12.1 MB 2.0 MB/s eta 0:00:03
#    ----------------------- ---------------- 7.1/12.1 MB 1.9 MB/s eta 0:00:03
#    ------------------------ --------------- 7.3/12.1 MB 1.8 MB/s eta 0:00:03
#    ------------------------- -------------- 7.9/12.1 MB 1.8 MB/s eta 0:00:03
#    --------------------------- ------------ 8.4/12.1 MB 1.9 MB/s eta 0:00:02
#    ---------------------------- ----------- 8.7/12.1 MB 1.8 MB/s eta 0:00:02
#    ---------------------------- ----------- 8.7/12.1 MB 1.8 MB/s eta 0:00:02
#    ----------------------------- ---------- 8.9/12.1 MB 1.7 MB/s eta 0:00:02
#    ------------------------------ --------- 9.2/12.1 MB 1.7 MB/s eta 0:00:02
#    ------------------------------- -------- 9.4/12.1 MB 1.7 MB/s eta 0:00:02
#    -------------------------------- ------- 9.7/12.1 MB 1.7 MB/s eta 0:00:02
#    -------------------------------- ------- 10.0/12.1 MB 1.7 MB/s eta 0:00:02
#    --------------------------------- ------ 10.2/12.1 MB 1.6 MB/s eta 0:00:02
#    ---------------------------------- ----- 10.5/12.1 MB 1.6 MB/s eta 0:00:01
#    ------------------------------------- -- 11.3/12.1 MB 1.7 MB/s eta 0:00:01
#    -------------------------------------- - 11.8/12.1 MB 1.7 MB/s eta 0:00:01
#    ---------------------------------------- 12.1/12.1 MB 1.7 MB/s eta 0:00:00
# Downloading holidays-0.86-py3-none-any.whl (1.3 MB)
#    ---------------------------------------- 0.0/1.3 MB ? eta -:--:--
#    ---------------------------------------  1.3/1.3 MB 6.2 MB/s eta 0:00:01
#    ---------------------------------------- 1.3/1.3 MB 4.4 MB/s eta 0:00:00
# Downloading cmdstanpy-1.3.0-py3-none-any.whl (99 kB)
# Downloading stanio-0.5.1-py3-none-any.whl (8.1 kB)
# Downloading importlib_resources-6.5.2-py3-none-any.whl (37 kB)
# Installing collected packages: stanio, importlib_resources, holidays, cmdstanpy, prophet
#
#    ---------------------------------------- 0/5 [stanio]
#    -------- ------------------------------- 1/5 [importlib_resources]
#    -------- ------------------------------- 1/5 [importlib_resources]
#    -------- ------------------------------- 1/5 [importlib_resources]
#    -------- ------------------------------- 1/5 [importlib_resources]
#    -------- ------------------------------- 1/5 [importlib_resources]
#    -------- ------------------------------- 1/5 [importlib_resources]
#    -------- ------------------------------- 1/5 [importlib_resources]
#    ---------------- ----------------------- 2/5 [holidays]
#    ---------------- ----------------------- 2/5 [holidays]
#    ---------------- ----------------------- 2/5 [holidays]
#    ---------------- ----------------------- 2/5 [holidays]
#    ---------------- ----------------------- 2/5 [holidays]
#    ---------------- ----------------------- 2/5 [holidays]
#    ---------------- ----------------------- 2/5 [holidays]
#    ---------------- ----------------------- 2/5 [holidays]
#    ---------------- ----------------------- 2/5 [holidays]
#    ---------------- ----------------------- 2/5 [holidays]
#    ---------------- ----------------------- 2/5 [holidays]
#    ---------------- ----------------------- 2/5 [holidays]
#    ---------------- ----------------------- 2/5 [holidays]
#    ---------------- ----------------------- 2/5 [holidays]
#    ---------------- ----------------------- 2/5 [holidays]
#    ---------------- ----------------------- 2/5 [holidays]
#    ---------------- ----------------------- 2/5 [holidays]
#    ---------------- ----------------------- 2/5 [holidays]
#    ---------------- ----------------------- 2/5 [holidays]
#    ---------------- ----------------------- 2/5 [holidays]
#    ---------------- ----------------------- 2/5 [holidays]
#    ---------------- ----------------------- 2/5 [holidays]
#    ---------------- ----------------------- 2/5 [holidays]
#    ---------------- ----------------------- 2/5 [holidays]
#    ---------------- ----------------------- 2/5 [holidays]
#    ---------------- ----------------------- 2/5 [holidays]
#    ---------------- ----------------------- 2/5 [holidays]
#    ---------------- ----------------------- 2/5 [holidays]
#    ---------------- ----------------------- 2/5 [holidays]
#    ---------------- ----------------------- 2/5 [holidays]
#    ---------------- ----------------------- 2/5 [holidays]
#    ---------------- ----------------------- 2/5 [holidays]
#    ---------------- ----------------------- 2/5 [holidays]
#    ---------------- ----------------------- 2/5 [holidays]
#    ---------------- ----------------------- 2/5 [holidays]
#    ---------------- ----------------------- 2/5 [holidays]
#    ---------------- ----------------------- 2/5 [holidays]
#    ---------------- ----------------------- 2/5 [holidays]
#    ---------------- ----------------------- 2/5 [holidays]
#    ---------------- ----------------------- 2/5 [holidays]
#    ---------------- ----------------------- 2/5 [holidays]
#    ---------------- ----------------------- 2/5 [holidays]
#    ---------------- ----------------------- 2/5 [holidays]
#    ---------------- ----------------------- 2/5 [holidays]
#    ---------------- ----------------------- 2/5 [holidays]
#    ---------------- ----------------------- 2/5 [holidays]
#    ---------------- ----------------------- 2/5 [holidays]
#    ---------------- ----------------------- 2/5 [holidays]
#    ---------------- ----------------------- 2/5 [holidays]
#    ---------------- ----------------------- 2/5 [holidays]
#    ---------------- ----------------------- 2/5 [holidays]
#    ---------------- ----------------------- 2/5 [holidays]
#    ---------------- ----------------------- 2/5 [holidays]
#    ---------------- ----------------------- 2/5 [holidays]
#    ---------------- ----------------------- 2/5 [holidays]
#    ---------------- ----------------------- 2/5 [holidays]
#    ---------------- ----------------------- 2/5 [holidays]
#    ---------------- ----------------------- 2/5 [holidays]
#    ---------------- ----------------------- 2/5 [holidays]
#    ---------------- ----------------------- 2/5 [holidays]
#    ---------------- ----------------------- 2/5 [holidays]
#    ---------------- ----------------------- 2/5 [holidays]
#    ---------------- ----------------------- 2/5 [holidays]
#    ---------------- ----------------------- 2/5 [holidays]
#    ---------------- ----------------------- 2/5 [holidays]
#    ---------------- ----------------------- 2/5 [holidays]
#    ---------------- ----------------------- 2/5 [holidays]
#    ---------------- ----------------------- 2/5 [holidays]
#    ---------------- ----------------------- 2/5 [holidays]
#    ---------------- ----------------------- 2/5 [holidays]
#    ---------------- ----------------------- 2/5 [holidays]
#    ---------------- ----------------------- 2/5 [holidays]
#    ---------------- ----------------------- 2/5 [holidays]
#    ---------------- ----------------------- 2/5 [holidays]
#    ---------------- ----------------------- 2/5 [holidays]
#    ---------------- ----------------------- 2/5 [holidays]
#    ---------------- ----------------------- 2/5 [holidays]
#    ---------------- ----------------------- 2/5 [holidays]
#    ---------------- ----------------------- 2/5 [holidays]
#    ---------------- ----------------------- 2/5 [holidays]
#    ---------------- ----------------------- 2/5 [holidays]
#    ---------------- ----------------------- 2/5 [holidays]
#    ---------------- ----------------------- 2/5 [holidays]
#    ---------------- ----------------------- 2/5 [holidays]
#    ---------------- ----------------------- 2/5 [holidays]
#    ---------------- ----------------------- 2/5 [holidays]
#    ---------------- ----------------------- 2/5 [holidays]
#    ---------------- ----------------------- 2/5 [holidays]
#    ---------------- ----------------------- 2/5 [holidays]
#    ---------------- ----------------------- 2/5 [holidays]
#    ---------------- ----------------------- 2/5 [holidays]
#    ---------------- ----------------------- 2/5 [holidays]
#    ---------------- ----------------------- 2/5 [holidays]
#    ---------------- ----------------------- 2/5 [holidays]
#    ------------------------ --------------- 3/5 [cmdstanpy]
#    ------------------------ --------------- 3/5 [cmdstanpy]
#    ------------------------ --------------- 3/5 [cmdstanpy]
#    ------------------------ --------------- 3/5 [cmdstanpy]
#    ------------------------ --------------- 3/5 [cmdstanpy]
#    ------------------------ --------------- 3/5 [cmdstanpy]
#    ------------------------ --------------- 3/5 [cmdstanpy]
#    -------------------------------- ------- 4/5 [prophet]
#    -------------------------------- ------- 4/5 [prophet]
#    -------------------------------- ------- 4/5 [prophet]
#    -------------------------------- ------- 4/5 [prophet]
#    -------------------------------- ------- 4/5 [prophet]
#    -------------------------------- ------- 4/5 [prophet]
#    -------------------------------- ------- 4/5 [prophet]
#    -------------------------------- ------- 4/5 [prophet]
#    -------------------------------- ------- 4/5 [prophet]
#    -------------------------------- ------- 4/5 [prophet]
#    -------------------------------- ------- 4/5 [prophet]
#    -------------------------------- ------- 4/5 [prophet]
#    -------------------------------- ------- 4/5 [prophet]
#    -------------------------------- ------- 4/5 [prophet]
#    ---------------------------------------- 5/5 [prophet]
#
# Successfully installed cmdstanpy-1.3.0 holidays-0.86 importlib_resources-6.5.2 prophet-1.2.1 stanio-0.5.1

# %% [markdown]
# #### 1. Importing the Necessary Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import prophet

# %% [markdown]
# #### 2. Loading the Dataset

# %%
gold_df=pd.read_csv("Gold Price.csv")

# %%
gold_df
# Out:
#             Date  Price   Open   High    Low  Volume  Chg%
# 0     2024-11-06  77030  78300  78570  77030       0 -1.86
# 1     2024-11-05  78490  78224  78670  78160       0  0.11
# 2     2024-11-04  78401  78498  78642  78237       0 -0.54
# 3     2024-11-01  78829  78650  78887  78550       0  0.64
# 4     2024-10-31  78326  79264  79999  77803      90 -1.17
# ...          ...    ...    ...    ...    ...     ...   ...
# 2801  2014-01-06  29119  29300  29395  29051   24380 -0.55
# 2802  2014-01-04  29279  29279  29279  29279       0 -1.51
# 2803  2014-01-03  29727  30031  30125  29539    3050 -0.83
# 2804  2014-01-02  29975  29678  30050  29678    3140  1.47
# 2805  2014-01-01  29542  29435  29598  29340    2930  0.25
#
# [2806 rows x 7 columns]

# %% [markdown]
# #### Checking for Missing Values

# %%
gold_df.isnull().sum()
# Out:
# Date      0
# Price     0
# Open      0
# High      0
# Low       0
# Volume    0
# Chg%      0
# dtype: int64

# %% [markdown]
# #### Checking for Datatypes

# %%
gold_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2806 entries, 0 to 2805
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    2806 non-null   object
#  1   Price   2806 non-null   int64
#  2   Open    2806 non-null   int64
#  3   High    2806 non-null   int64
#  4   Low     2806 non-null   int64
#  5   Volume  2806 non-null   int64
#  6   Chg%    2806 non-null   float64
# dtypes: float64(1), int64(5), object(1)
# memory usage: 153.6+ KB

# %% [markdown]
# #### we can see that Date is not in proper Date time format so we need to change it

# %%
gold_df['Date'] = pd.to_datetime(gold_df['Date'])
#formating into datatime, important for the analysis

# %%
gold_df.Date
# Out:
# 0      2024-11-06
# 1      2024-11-05
# 2      2024-11-04
# 3      2024-11-01
# 4      2024-10-31
#           ...
# 2801   2014-01-06
# 2802   2014-01-04
# 2803   2014-01-03
# 2804   2014-01-02
# 2805   2014-01-01
# Name: Date, Length: 2806, dtype: datetime64[ns]

# %%
gold_df['Price'].hist(bins=50, figsize=(10,6))
plt.title('Distribution of Price')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# - The price distribution shows multiple peaks, indicating different market phases.
# Gold prices are not concentrated in one range — instead, they form clusters around ₹28k, ₹48k, ₹60k, and ₹72k, showing how gold moved through several major price cycles over the years.
#
# - Most of the observations fall between ₹27,000–₹32,000 and ₹47,000–₹52,000.
# These ranges represent the highest trading frequency, meaning gold spent more time in these price bands compared to extremely high-price ranges like ₹70,000+.

# %%
#Yearly analysis
gold_df.index=pd.DatetimeIndex(gold_df.Date)

# %%
gold_df.resample('YE').size()
# Out:
# Date
# 2014-12-31    268
# 2015-12-31    262
# 2016-12-31    259
# 2017-12-31    255
# 2018-12-31    256
# 2019-12-31    257
# 2020-12-31    258
# 2021-12-31    259
# 2022-12-31    257
# 2023-12-31    256
# 2024-12-31    219
# Freq: YE-DEC, dtype: int64

# %%
gold_df.reset_index(drop=True)
# Out:
#            Date  Price   Open   High    Low  Volume  Chg%
# 0    2024-11-06  77030  78300  78570  77030       0 -1.86
# 1    2024-11-05  78490  78224  78670  78160       0  0.11
# 2    2024-11-04  78401  78498  78642  78237       0 -0.54
# 3    2024-11-01  78829  78650  78887  78550       0  0.64
# 4    2024-10-31  78326  79264  79999  77803      90 -1.17
# ...         ...    ...    ...    ...    ...     ...   ...
# 2801 2014-01-06  29119  29300  29395  29051   24380 -0.55
# 2802 2014-01-04  29279  29279  29279  29279       0 -1.51
# 2803 2014-01-03  29727  30031  30125  29539    3050 -0.83
# 2804 2014-01-02  29975  29678  30050  29678    3140  1.47
# 2805 2014-01-01  29542  29435  29598  29340    2930  0.25
#
# [2806 rows x 7 columns]

# %%
plt.figure(figsize=(25,25))
plt.plot(gold_df.groupby(gold_df['Date'])['Price'].mean())

# %%
gold_df.set_index('Date', inplace=True)
monthly_avg_price = gold_df['Price'].resample('ME').mean()

# %%
monthly_avg_price
# Out:
# Date
# 2014-01-31    29386.500000
# 2014-02-28    30184.450000
# 2014-03-31    30100.190476
# 2014-04-30    29199.521739
# 2014-05-31    28373.636364
#                   ...
# 2024-07-31    71475.913043
# 2024-08-31    70412.666667
# 2024-09-30    73038.857143
# 2024-10-31    76716.272727
# 2024-11-30    78187.500000
# Freq: ME, Name: Price, Length: 131, dtype: float64

# %%
gold_df.tail(24).Price.mean()
# Out:
# np.float64(29386.5)

# %%
monthly_avg_price.index
# Out:
# DatetimeIndex(['2014-01-31', '2014-02-28', '2014-03-31', '2014-04-30',
#                '2014-05-31', '2014-06-30', '2014-07-31', '2014-08-31',
#                '2014-09-30', '2014-10-31',
#                ...
#                '2024-02-29', '2024-03-31', '2024-04-30', '2024-05-31',
#                '2024-06-30', '2024-07-31', '2024-08-31', '2024-09-30',
#                '2024-10-31', '2024-11-30'],
#               dtype='datetime64[ns]', name='Date', length=131, freq='ME')

# %%
# Now will perform for every 6 Months 
monthly_avg_price.index[::6]
# Out:
# DatetimeIndex(['2014-01-31', '2014-07-31', '2015-01-31', '2015-07-31',
#                '2016-01-31', '2016-07-31', '2017-01-31', '2017-07-31',
#                '2018-01-31', '2018-07-31', '2019-01-31', '2019-07-31',
#                '2020-01-31', '2020-07-31', '2021-01-31', '2021-07-31',
#                '2022-01-31', '2022-07-31', '2023-01-31', '2023-07-31',
#                '2024-01-31', '2024-07-31'],
#               dtype='datetime64[ns]', name='Date', freq='6ME')

# %%
monthly_avg_price.index.strftime('%b %Y')
# Out:
# Index(['Jan 2014', 'Feb 2014', 'Mar 2014', 'Apr 2014', 'May 2014', 'Jun 2014',
#        'Jul 2014', 'Aug 2014', 'Sep 2014', 'Oct 2014',
#        ...
#        'Feb 2024', 'Mar 2024', 'Apr 2024', 'May 2024', 'Jun 2024', 'Jul 2024',
#        'Aug 2024', 'Sep 2024', 'Oct 2024', 'Nov 2024'],
#       dtype='object', name='Date', length=131)

# %%
# Now will perform for every 6 Months 
plt.figure(figsize=(25,25))
plt.plot(monthly_avg_price)
plt.xticks(monthly_avg_price.index[::6], monthly_avg_price.index.strftime('%b %Y')[::6], rotation=45)  # every 6 months
# Out:
# ([<matplotlib.axis.XTick at 0x2914b3a5e50>,
#   <matplotlib.axis.XTick at 0x2914b420190>,
#   <matplotlib.axis.XTick at 0x2914b420e10>,
#   <matplotlib.axis.XTick at 0x2914b421590>,
#   <matplotlib.axis.XTick at 0x2914b421d10>,
#   <matplotlib.axis.XTick at 0x291498b9a90>,
#   <matplotlib.axis.XTick at 0x2914b253890>,
#   <matplotlib.axis.XTick at 0x2914b253250>,
#   <matplotlib.axis.XTick at 0x2914b4e20d0>,
#   <matplotlib.axis.XTick at 0x2914b4e2850>,
#   <matplotlib.axis.XTick at 0x2914b4e2fd0>,
#   <matplotlib.axis.XTick at 0x2914b4e3750>,
#   <matplotlib.axis.XTick at 0x2914b4e3ed0>,
#   <matplotlib.axis.XTick at 0x2914b3f4690>,
#   <matplotlib.axis.XTick at 0x2914b3f4e10>,
#   <matplotlib.axis.XTick at 0x2914b3f5590>,
#   <matplotlib.axis.XTick at 0x2914b3f5d10>,
#   <matplotlib.axis.XTick at 0x2914b3f6490>,
#   <matplotlib.axis.XTick at 0x2914b3f6c10>,
#   <matplotlib.axis.XTick at 0x2914b3f7390>,
#   <matplotlib.axis.XTick at 0x2914b3f7b10>,
#   <matplotlib.axis.XTick at 0x2914b3dc2d0>],
#  [Text(16101.0, 0, 'Jan 2014'),
#   Text(16282.0, 0, 'Jul 2014'),
#   Text(16466.0, 0, 'Jan 2015'),
#   Text(16647.0, 0, 'Jul 2015'),
#   Text(16831.0, 0, 'Jan 2016'),
#   Text(17013.0, 0, 'Jul 2016'),
#   Text(17197.0, 0, 'Jan 2017'),
#   Text(17378.0, 0, 'Jul 2017'),
#   Text(17562.0, 0, 'Jan 2018'),
#   Text(17743.0, 0, 'Jul 2018'),
#   Text(17927.0, 0, 'Jan 2019'),
#   Text(18108.0, 0, 'Jul 2019'),
#   Text(18292.0, 0, 'Jan 2020'),
#   Text(18474.0, 0, 'Jul 2020'),
#   Text(18658.0, 0, 'Jan 2021'),
#   Text(18839.0, 0, 'Jul 2021'),
#   Text(19023.0, 0, 'Jan 2022'),
#   Text(19204.0, 0, 'Jul 2022'),
#   Text(19388.0, 0, 'Jan 2023'),
#   Text(19569.0, 0, 'Jul 2023'),
#   Text(19753.0, 0, 'Jan 2024'),
#   Text(19935.0, 0, 'Jul 2024')])

# %%
monthly_avg_price
# Out:
# Date
# 2014-01-31    29386.500000
# 2014-02-28    30184.450000
# 2014-03-31    30100.190476
# 2014-04-30    29199.521739
# 2014-05-31    28373.636364
#                   ...
# 2024-07-31    71475.913043
# 2024-08-31    70412.666667
# 2024-09-30    73038.857143
# 2024-10-31    76716.272727
# 2024-11-30    78187.500000
# Freq: ME, Name: Price, Length: 131, dtype: float64

# %%
#doing the prediction using Prophet time series model

# %%
from prophet import Prophet

# Create an instance of the Prophet model
d = Prophet()

# %%
fin=gold_df['Price'].reset_index()

# %%
fin.head()
# Out:
#         Date  Price
# 0 2024-11-06  77030
# 1 2024-11-05  78490
# 2 2024-11-04  78401
# 3 2024-11-01  78829
# 4 2024-10-31  78326

# %%
fin=fin.rename(columns={'Date':'ds','Price':'y'})

# %%
d.fit(fin)
# Out:
# 03:42:38 - cmdstanpy - INFO - Chain [1] start processing
# 03:42:39 - cmdstanpy - INFO - Chain [1] done processing

# %%
future=d.make_future_dataframe(periods=365)
forecast=d.predict(future)

# %%
d.plot(forecast)

# %%
d.plot_components(forecast)

# %% [markdown]
# INTERPRETATIONS OF THE GRAPHS:
# 1) In the weekly trend it is noticed that the price increases on monday when the markets open and a similar trend is noticed on Friday when the markets close
# 2) In the yearly trend it is noticed that the price increases before May, this could be because of the Hindu festival called Akshay Tritiya, and then constant decline, with a mild peak around November
# 3) The model predicted the gold price for the year 2025 to reach a peak of 90000 or a low of around 78000, The current price of 22-carat gold per gram in Delhi today is ₹9,305. It was priced at ₹9,030
